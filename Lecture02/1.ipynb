# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ### Series
# Она представляет из себя объект, похожий на одномерный массив, но отличительной чертой является наличие индексов. Индекс находится слева, а сам элемент справа.
#
# Синтаксис создания:
# pandas.Series(input_data, index, data_type)

# %% [markdown]
# - input_data: ввод в виде списка, константы, массива NumPy, Dict и т. д.
# - index: значения индексов.
# - data_type (опционально): тип данных.

# %%
a = pd.Series([4, 7, 6, 3, 9],
        index=['one', 'two', 'three', 'four', 'five'])
a
# Out:
# one      4
# two      7
# three    6
# four     3
# five     9
# dtype: int64

# %%
a = pd.Series([4, 7, 6, 3, 9])
a
# Out:
# 0    4
# 1    7
# 2    6
# 3    3
# 4    9
# dtype: int64

# %%
a.index
# Out:
# Index(['one', 'two', 'three', 'four', 'five'], dtype='object')

# %%
a.values  # значения
# Out:
# array([4, 7, 6, 3, 9], dtype=int64)

# %%
a[0]   # используем индексы для возвращения значений
# Out:
# 4

# %%
a[1]
# Out:
# 7

# %%
a['one']
# Out:
# 4

# %% [markdown]
# ### DataFrame
# Объект DataFrame является табличной структурой данных. В любой таблице всегда присутствуют строки и столбцы. При этом в столбцах можно хранить данные разных типов данных. Столбцами в объекте DataFrame выступают объекты Series, строки которых являются их элементами.
#
# Синтаксис создания:
# pandas.DataFrame(input_data, index)
# - input_data: ввод в виде Dict, 2D массива NumPy, Series и т. д.
# - index: значения индексов.

# %%
df = pd.DataFrame({
    'Age': [46, 37, 44, 42, 42],
    'Country': ['Spain', 'Spain', 'Germany', 'Germany', 'France'],
    'Gender': ['Female', 'Female', 'Male', 'Male', 'Male']
})

df
# Out:
#    Age  Country  Gender
# 0   46    Spain  Female
# 1   37    Spain  Female
# 2   44  Germany    Male
# 3   42  Germany    Male
# 4   42   France    Male

# %%
df['Age']
# Out:
# 0    46
# 1    37
# 2    44
# 3    42
# 4    42
# Name: Age, dtype: int64

# %%
df.Country  #  обращение как к атрибуту класса  (.)
# Out:
# 0      Spain
# 1      Spain
# 2    Germany
# 3    Germany
# 4     France
# Name: Country, dtype: object

# %%
df[['Country', 'Age']]  # чтобы взять несколько столбиков []
# Out:
#    Country  Age
# 0    Spain   46
# 1    Spain   37
# 2  Germany   44
# 3  Germany   42
# 4   France   42

# %%
df.columns  #  колонки
# Out:
# Index(['Age', 'Country', 'Gender'], dtype='object')

# %%
df.index     # индекс дефолтный
# Out:
# RangeIndex(start=0, stop=5, step=1)

# %% [markdown]
# берём словарь данных задаём индексы index=[5, 4, 6, 3, 2])

# %%
df = pd.DataFrame({
    'Age': [46, 37, 44, 42, 42],
    'Country': ['Spain', 'Spain', 'Germany', 'Germany', 'France'],
    'Gender': ['Female', 'Female', 'Male', 'Male', 'Male']
}, index=[5, 4, 6, 3, 2])

df
# Out:
#    Age  Country  Gender
# 5   46    Spain  Female
# 4   37    Spain  Female
# 6   44  Germany    Male
# 3   42  Germany    Male
# 2   42   France    Male

# %% [markdown]
# меняем индексы

# %%
df.index = [101, 102, 103, 104, 105]
df
# Out:
#      Age  Country  Gender
# 101   46    Spain  Female
# 102   37    Spain  Female
# 103   44  Germany    Male
# 104   42  Germany    Male
# 105   42   France    Male

# %% [markdown]
# ### Считывание данных
# В целом, pandas поддерживает все самые популярные форматы хранения данных: csv, excel, sql, html и многое другое, но чаще всего приходится работать именно с csv файлами (comma separated values).

# %% [markdown]
# Будем работать с датасетом по оттоку клиентов из банка
# https://www.kaggle.com/datasets/shubh0799/churn-modelling.

# %% [markdown]
# Характеристики каждого клиента:
#
# 1. RowNumber - Номер строки
# 2. CustomerId - Уникальный идентификатор клиента
# 3. Surname - Фамилия клиента
# 4. reditScore - Кредитная оценка клиента
# 5. Geography - Из какой страны клиент
# 6. Gender - Пол клиента
# 7. Age - Возраст клиента
# 8. Tenure - Сколько лет человек является клиентом банка
# 9. Balance - Баланс счета
# 10. NumOfProducts - Количество открытых продуктов
# 11. HasCrCard - Есть ли у клиента кредитная карта
# 12. IsActiveMember - Является ли клиент активные участником
# 13. EstimatedSalary - Предположительная зарплата клиента
# 14. Exited - Уйдет ли человек в отток.

# %%
df = pd.read_csv('./Churn_Modelling.csv')
df
# Out:
#       RowNumber  CustomerId    Surname  CreditScore Geography  Gender  Age  \
# 0             1    15634602   Hargrave          619    France  Female   42
# 1             2    15647311       Hill          608     Spain  Female   41
# 2             3    15619304       Onio          502    France  Female   42
# 3             4    15701354       Boni          699    France  Female   39
# 4             5    15737888   Mitchell          850     Spain  Female   43
# ...         ...         ...        ...          ...       ...     ...  ...
# 9995       9996    15606229   Obijiaku          771    France    Male   39
# 9996       9997    15569892  Johnstone          516    France    Male   35
# 9997       9998    15584532        Liu          709    France  Female   36
# 9998       9999    15682355  Sabbatini          772   Germany    Male   42
# 9999      10000    15628319     Walker          792    France  Female   28
#
#       Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# ...

# %%
pd.read_csv('./Churn_Modelling.csv', header=1)  # header=1) - Заголовок (шапка)на 1 строчке
# Out:
#           1  15634602   Hargrave  619   France  Female  42   2          0  \
# 0         2  15647311       Hill  608    Spain  Female  41   1   83807.86
# 1         3  15619304       Onio  502   France  Female  42   8  159660.80
# 2         4  15701354       Boni  699   France  Female  39   1       0.00
# 3         5  15737888   Mitchell  850    Spain  Female  43   2  125510.82
# 4         6  15574012        Chu  645    Spain    Male  44   8  113755.78
# ...     ...       ...        ...  ...      ...     ...  ..  ..        ...
# 9994   9996  15606229   Obijiaku  771   France    Male  39   5       0.00
# 9995   9997  15569892  Johnstone  516   France    Male  35  10   57369.61
# 9996   9998  15584532        Liu  709   France  Female  36   7       0.00
# 9997   9999  15682355  Sabbatini  772  Germany    Male  42   3   75075.31
# 9998  10000  15628319     Walker  792   France  Female  28   4  130142.79
#
#       1.1  1.2  1.3  101348.88  1.4
# 0       1    0    1  112542.58    0
# ...

# %%
pd.read_csv('./Churn_Modelling.csv', sep=';')  # Разделение данных  sep=',') для нормального чтения
# Out:
#      RowNumber,CustomerId,Surname,CreditScore,Geography,Gender,Age,Tenure,Balance,NumOfProducts,HasCrCard,IsActiveMember,EstimatedSalary,Exited
# 0     1,15634602,Hargrave,619,France,Female,42,2,0,1...
# 1     2,15647311,Hill,608,Spain,Female,41,1,83807.86...
# 2     3,15619304,Onio,502,France,Female,42,8,159660....
# 3     4,15701354,Boni,699,France,Female,39,1,0,2,0,0...
# 4     5,15737888,Mitchell,850,Spain,Female,43,2,1255...
# ...                                                 ...
# 9995  9996,15606229,Obijiaku,771,France,Male,39,5,0,...
# 9996  9997,15569892,Johnstone,516,France,Male,35,10,...
# 9997  9998,15584532,Liu,709,France,Female,36,7,0,1,0...
# 9998  9999,15682355,Sabbatini,772,Germany,Male,42,3,...
# 9999  10000,15628319,Walker,792,France,Female,28,4,1...
#
# [10000 rows x 1 columns]

# %%
df      # название переменной для вывода таблицы
# Out:
#       RowNumber  CustomerId    Surname  CreditScore Geography  Gender  Age  \
# 0             1    15634602   Hargrave          619    France  Female   42
# 1             2    15647311       Hill          608     Spain  Female   41
# 2             3    15619304       Onio          502    France  Female   42
# 3             4    15701354       Boni          699    France  Female   39
# 4             5    15737888   Mitchell          850     Spain  Female   43
# ...         ...         ...        ...          ...       ...     ...  ...
# 9995       9996    15606229   Obijiaku          771    France    Male   39
# 9996       9997    15569892  Johnstone          516    France    Male   35
# 9997       9998    15584532        Liu          709    France  Female   36
# 9998       9999    15682355  Sabbatini          772   Germany    Male   42
# 9999      10000    15628319     Walker          792    France  Female   28
#
#       Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# ...

# %%
df.head() # head()-выводит по умолчанию 5 элементов с верха или указываем в методе то количество строк которое хотим возвращать
# Out:
#    RowNumber  CustomerId   Surname  CreditScore Geography  Gender  Age  \
# 0          1    15634602  Hargrave          619    France  Female   42
# 1          2    15647311      Hill          608     Spain  Female   41
# 2          3    15619304      Onio          502    France  Female   42
# 3          4    15701354      Boni          699    France  Female   39
# 4          5    15737888  Mitchell          850     Spain  Female   43
#
#    Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0       2       0.00              1          1               1
# 1       1   83807.86              1          0               1
# 2       8  159660.80              3          1               0
# 3       1       0.00              2          0               0
# 4       2  125510.82              1          1               1
#
#    EstimatedSalary  Exited
# 0        101348.88       1
# 1        112542.58       0
# 2        113931.57       1
# 3         93826.63       0
# ...

# %%
df.tail() # берём 5 элементов с конца, или указываем количество которое нужно возвратить ()
# Out:
#       RowNumber  CustomerId    Surname  CreditScore Geography  Gender  Age  \
# 9995       9996    15606229   Obijiaku          771    France    Male   39
# 9996       9997    15569892  Johnstone          516    France    Male   35
# 9997       9998    15584532        Liu          709    France  Female   36
# 9998       9999    15682355  Sabbatini          772   Germany    Male   42
# 9999      10000    15628319     Walker          792    France  Female   28
#
#       Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 9995       5       0.00              2          1               0
# 9996      10   57369.61              1          1               1
# 9997       7       0.00              1          0               1
# 9998       3   75075.31              2          1               0
# 9999       4  130142.79              1          1               0
#
#       EstimatedSalary  Exited
# 9995         96270.64       0
# 9996        101699.77       0
# ...

# %%
df.sample()  # возвращаем случайную строку из таблицы
# Out:
#      RowNumber  CustomerId Surname  CreditScore Geography Gender  Age  Tenure  \
# 506        507    15805565  Obiuto          691   Germany   Male   30       7
#
#        Balance  NumOfProducts  HasCrCard  IsActiveMember  EstimatedSalary  \
# 506  116927.89              1          1               0         21198.39
#
#      Exited
# 506       0

# %%
df.sample(frac=1) # доля возвращаемых обьектов  если указать (frac=1) - то все строки будут в случайном порядке
# Out:
#       RowNumber  CustomerId    Surname  CreditScore Geography  Gender  Age  \
# 3710       3711    15601796   Chizuoke          645    France    Male   30
# 1211       1212    15738174      Ervin          452    France  Female   32
# 5705       5706    15698703    Doherty          628   Germany    Male   40
# 4035       4036    15792607     Little          769    France  Female   38
# 6170       6171    15611157   McElhone          709    France  Female   32
# ...         ...         ...        ...          ...       ...     ...  ...
# 5978       5979    15713770       Shih          586     Spain    Male   41
# 7763       7764    15767064     Davide          614     Spain  Female   36
# 399         400    15646372  Outhwaite          616    France  Female   66
# 5177       5178    15588449     Chuang          591     Spain  Female   27
# 7509       7510    15657228   Anderson          545   Germany    Male   37
#
#       Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# ...

# %%
df.sample(frac=0.5)   # доля возвращаемых обьектов  если указать (frac=0.5) - то вернётся половина данных
# Out:
#       RowNumber  CustomerId   Surname  CreditScore Geography  Gender  Age  \
# 2696       2697    15792176     Henty          698     Spain  Female   40
# 7637       7638    15604196   Simpson          766    France    Male   32
# 1829       1830    15605275   Ofodile          725   Germany    Male   45
# 8461       8462    15758769    Coffey          625    France  Female   44
# 6519       6520    15571869       Lei          669   Germany  Female   50
# ...         ...         ...       ...          ...       ...     ...  ...
# 2301       2302    15757577     Odili          676    France  Female   61
# 8131       8132    15803352     Scott          613   Germany    Male   33
# 4766       4767    15719858      Chao          659     Spain  Female   38
# 4489       4490    15787035  Anderson          602    France  Female   35
# 929         930    15590876     Knupp          764    France  Female   24
#
#       Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# ...

# %%
df.shape  #  узнать размерность таблицы возвращает кортеж 1 - значение строк, 2 - значение столбцов
# Out:
# (10000, 14)

# %% [markdown]
# ### Первичный анализ данных
# Типы данных:
#
# - int: целочисленные значения. Пример: 9, 56, 30
# - float: вещественные значения (с плавающей точкой). Пример: 7.3, 9.0, 45.334
# - object/str: строковые значения. Пример: ‘hello, world’, ‘50 000’

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   RowNumber        10000 non-null  int64
#  1   CustomerId       10000 non-null  int64
#  2   Surname          10000 non-null  object
#  3   CreditScore      10000 non-null  int64
#  4   Geography        10000 non-null  object
#  5   Gender           10000 non-null  object
#  6   Age              10000 non-null  int64
#  7   Tenure           10000 non-null  int64
#  8   Balance          10000 non-null  float64
#  9   NumOfProducts    10000 non-null  int64
#  10  HasCrCard        10000 non-null  int64
#  11  IsActiveMember   10000 non-null  int64
#  12  EstimatedSalary  10000 non-null  float64
#  13  Exited           10000 non-null  int64
# dtypes: float64(2), int64(9), object(3)
# memory usage: 1.1+ MB

# %% [markdown]
# ##### Выводятся значения:
#
# - Count - количество непропущенных объектов (там, где нет nan значений)
# - mean - арифметическое среднее
# - std - стандартное отклонение
# - min - минимальное значение
# - 25% - квантиль 25 процентов
# - 50% - квантиль 50 процентов или же медиана
# - 75% - квантиль 75 процентов
# - max - максимальное значение

# %%
df.describe()    # возвращает основную сводную статистику, по умолчанию не возвращает строковаые и булевые значения
# Out:
#          RowNumber    CustomerId   CreditScore           Age        Tenure  \
# count  10000.00000  1.000000e+04  10000.000000  10000.000000  10000.000000
# mean    5000.50000  1.569094e+07    650.528800     38.921800      5.012800
# std     2886.89568  7.193619e+04     96.653299     10.487806      2.892174
# min        1.00000  1.556570e+07    350.000000     18.000000      0.000000
# 25%     2500.75000  1.562853e+07    584.000000     32.000000      3.000000
# 50%     5000.50000  1.569074e+07    652.000000     37.000000      5.000000
# 75%     7500.25000  1.575323e+07    718.000000     44.000000      7.000000
# max    10000.00000  1.581569e+07    850.000000     92.000000     10.000000
#
#              Balance  NumOfProducts    HasCrCard  IsActiveMember  \
# count   10000.000000   10000.000000  10000.00000    10000.000000
# mean    76485.889288       1.530200      0.70550        0.515100
# std     62397.405202       0.581654      0.45584        0.499797
# ...

# %%
df['Age'].min()  # min - минимальное
# Out:
# 18

# %%
df['Balance'].max()  # max - максимальное
# Out:
# 250898.09

# %%
df[['CreditScore', 'Age', 'Tenure']].mean()  # mean - среднее по каждому признаку
# Out:
# CreditScore    650.5288
# Age             38.9218
# Tenure           5.0128
# dtype: float64

# %% [markdown]
# Получаем 4 значения:
#
# - count - количество непропущенных объектов
# - unique - количество уникальных значений
# - top - самое частотное значение (мода)
# - freq - частота появления самого частотного значения

# %%
df.describe(include=['object'])   # include=['']) -  указывакем те типы данных которые хотим увидеть
# Out:
#        Surname Geography Gender
# count    10000     10000  10000
# unique    2932         3      2
# top      Smith    France   Male
# freq        32      5014   5457

# %%
df.dtypes  # узнать типы данных
# Out:
# RowNumber            int64
# CustomerId           int64
# Surname             object
# CreditScore          int64
# Geography           object
# Gender              object
# Age                  int64
# Tenure               int64
# Balance            float64
# NumOfProducts        int64
# HasCrCard            int64
# IsActiveMember       int64
# EstimatedSalary    float64
# Exited               int64
# dtype: object

# %%
df['Age'].dtype    # узнать тип данных по одной из серий
# Out:
# dtype('int64')

# %%
df['HasCrCard'].astype('bool')  # astype - изменение типа данных с (int) на (bool) при этом исходный тип данных не меняется
# Out:
# 0        True
# 1       False
# 2        True
# 3       False
# 4        True
#         ...
# 9995     True
# 9996     True
# 9997    False
# 9998     True
# 9999     True
# Name: HasCrCard, Length: 10000, dtype: bool

# %%
df['HasCrCard'].dtype
# Out:
# dtype('int64')

# %%
df['HasCrCard'] = df['HasCrCard'].astype('bool')   #  изменение птипа данных переменной

# %%
df['HasCrCard'].dtype
# Out:
# dtype('bool')

# %%
df['Geography'].unique()  # взять уникальные обьекты
# Out:
# array(['France', 'Spain', 'Germany'], dtype=object)

# %%
df['Geography'].nunique()   # взять количество уникальных обьектов
# Out:
# 3

# %%
df['Geography'].value_counts() # частотность появления уникальных обьектов
# Out:
# France     5014
# Germany    2509
# Spain      2477
# Name: Geography, dtype: int64

# %%
df['Geography'].value_counts(normalize=True) # норамлизация получаем процентное соотношение уникальных обьектов
# Out:
# France     0.5014
# Germany    0.2509
# Spain      0.2477
# Name: Geography, dtype: float64

# %% [markdown]
# ### Фильтрация
# Фильтрация в pandas основывается на булевых масках.

# %% [markdown]
# ##### Булевая маска
# - бинарные данные, которые используются для выбора определенных объектов из структуры данных.

# %%
df['Gender'] == 'Male'
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 9995     True
# 9996     True
# 9997    False
# 9998     True
# 9999    False
# Name: Gender, Length: 10000, dtype: bool

# %%
male = df[df['Gender'] == 'Male']  #  используя маску по фильтрации получаем признак по 'Gender' только  (Male)
male
# Out:
#       RowNumber  CustomerId      Surname  CreditScore Geography Gender  Age  \
# 5             6    15574012          Chu          645     Spain   Male   44
# 6             7    15592531     Bartlett          822    France   Male   50
# 8             9    15792365           He          501    France   Male   44
# 9            10    15592389           H?          684    France   Male   27
# 10           11    15767821       Bearce          528    France   Male   31
# ...         ...         ...          ...          ...       ...    ...  ...
# 9992       9993    15657105  Chukwualuka          726     Spain   Male   36
# 9993       9994    15569266       Rahman          644    France   Male   28
# 9995       9996    15606229     Obijiaku          771    France   Male   39
# 9996       9997    15569892    Johnstone          516    France   Male   35
# 9998       9999    15682355    Sabbatini          772   Germany   Male   42
#
# ...

# %% [markdown]
# ### Логические И
# При операторе & нужно, чтобы выполнялось два условия одновременно:

# %%
df['Gender'] == 'Female'  #  булевая маска по 'Gender'
# Out:
# 0        True
# 1        True
# 2        True
# 3        True
# 4        True
#         ...
# 9995    False
# 9996    False
# 9997     True
# 9998    False
# 9999     True
# Name: Gender, Length: 10000, dtype: bool

# %%
df['NumOfProducts'] >= 3   # булевая маска по количеству продуктов
# Out:
# 0       False
# 1       False
# 2        True
# 3       False
# 4       False
#         ...
# 9995    False
# 9996    False
# 9997    False
# 9998    False
# 9999    False
# Name: NumOfProducts, Length: 10000, dtype: bool

# %%
(df['Gender'] == 'Female') & (df['NumOfProducts'] >= 3)   # совокупная булевая маска по 2 признакам
# Out:
# 0       False
# 1       False
# 2        True
# 3       False
# 4       False
#         ...
# 9995    False
# 9996    False
# 9997    False
# 9998    False
# 9999    False
# Length: 10000, dtype: bool

# %% [markdown]
# возвращаются только женщины у котрорых количество продуктов или  >= 3

# %%
df[(df['Gender'] == 'Female') & (df['NumOfProducts'] >= 3)]
# Out:
#       RowNumber  CustomerId        Surname  CreditScore Geography  Gender  \
# 2             3    15619304           Onio          502    France  Female
# 7             8    15656148         Obinna          376   Germany  Female
# 30           31    15589475        Azikiwe          591     Spain  Female
# 88           89    15622897         Sharpe          646    France  Female
# 90           91    15757535           Heap          647     Spain  Female
# ...         ...         ...            ...          ...       ...     ...
# 9565       9566    15752294           Long          582    France  Female
# 9747       9748    15775761  Iweobiegbunam          610   Germany  Female
# 9800       9801    15640507             Li          762     Spain  Female
# 9877       9878    15572182     Onwuamaeze          505   Germany  Female
# 9895       9896    15796764          Bruno          684   Germany  Female
#
#       Age  Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# ...

# %% [markdown]
# ### Логические ИЛИ
# При операторе | нужно, чтобы выполнялось хотя бы одно условие:

# %% [markdown]
#        (|) - либо выполнение 1 либо 2 условия, кредитная карта или количество продуктов >= 3

# %%
df[(df['HasCrCard']) | (df['NumOfProducts'] >= 3)]
# Out:
#       RowNumber  CustomerId    Surname  CreditScore Geography  Gender  Age  \
# 0             1    15634602   Hargrave          619    France  Female   42
# 2             3    15619304       Onio          502    France  Female   42
# 4             5    15737888   Mitchell          850     Spain  Female   43
# 5             6    15574012        Chu          645     Spain    Male   44
# 6             7    15592531   Bartlett          822    France    Male   50
# ...         ...         ...        ...          ...       ...     ...  ...
# 9993       9994    15569266     Rahman          644    France    Male   28
# 9995       9996    15606229   Obijiaku          771    France    Male   39
# 9996       9997    15569892  Johnstone          516    France    Male   35
# 9998       9999    15682355  Sabbatini          772   Germany    Male   42
# 9999      10000    15628319     Walker          792    France  Female   28
#
#       Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# ...

# %% [markdown]
# ### Логические НЕ
# При операторе ~ булевая маска обращается: True меняется на False и наоборот:

# %%
-(df['Geography'] == 'Spain')  # изменение логической маски  (-)
# Out:
# 0        True
# 1       False
# 2        True
# 3        True
# 4       False
#         ...
# 9995     True
# 9996     True
# 9997     True
# 9998     True
# 9999     True
# Name: Geography, Length: 10000, dtype: bool

# %%
df[~(df['Geography'] == 'Spain')]   # возвращаем всех клиентов кто не в 'Spain'
# Out:
#       RowNumber  CustomerId    Surname  CreditScore Geography  Gender  Age  \
# 0             1    15634602   Hargrave          619    France  Female   42
# 2             3    15619304       Onio          502    France  Female   42
# 3             4    15701354       Boni          699    France  Female   39
# 6             7    15592531   Bartlett          822    France    Male   50
# 7             8    15656148     Obinna          376   Germany  Female   29
# ...         ...         ...        ...          ...       ...     ...  ...
# 9995       9996    15606229   Obijiaku          771    France    Male   39
# 9996       9997    15569892  Johnstone          516    France    Male   35
# 9997       9998    15584532        Liu          709    France  Female   36
# 9998       9999    15682355  Sabbatini          772   Germany    Male   42
# 9999      10000    15628319     Walker          792    France  Female   28
#
#       Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# ...

# %%
df[df['Geography'].isin(['France', 'Germany'])]   # isin - показывает находится ли обьект  в 'France', 'Germany'
# Out:
#       RowNumber  CustomerId    Surname  CreditScore Geography  Gender  Age  \
# 0             1    15634602   Hargrave          619    France  Female   42
# 2             3    15619304       Onio          502    France  Female   42
# 3             4    15701354       Boni          699    France  Female   39
# 6             7    15592531   Bartlett          822    France    Male   50
# 7             8    15656148     Obinna          376   Germany  Female   29
# ...         ...         ...        ...          ...       ...     ...  ...
# 9995       9996    15606229   Obijiaku          771    France    Male   39
# 9996       9997    15569892  Johnstone          516    France    Male   35
# 9997       9998    15584532        Liu          709    France  Female   36
# 9998       9999    15682355  Sabbatini          772   Germany    Male   42
# 9999      10000    15628319     Walker          792    France  Female   28
#
#       Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# ...

# %% [markdown]
# ### Индексация

# %%
df_small = df[(df['Geography'] == 'Spain')][['Geography', 'Gender', 'Age']]  # взятие обьекта по индексу
df_small.head()
# Out:
#    Geography  Gender  Age
# 1      Spain  Female   41
# 4      Spain  Female   43
# 5      Spain    Male   44
# 11     Spain    Male   24
# 14     Spain  Female   35

# %% [markdown]
# ### loc

# %%
df_small.loc[1]      # берём 1 индекс
# Out:
# Geography     Spain
# Gender       Female
# Age              41
# Name: 1, dtype: object

# %%
df_small.loc[3]      # берём 3 индекс, такого индекса нет
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3628             try:
# -> 3629                 return self._engine.get_loc(casted_key)
#    3630             except KeyError as err:
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.Int64HashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.Int64HashTable.get_item()
#
# KeyError: 3
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %%
df_small.loc[[1, 4, 5], ['Gender', 'Age']]    #  комбинируем строчки и столбики, индексы должны существовать
# Out:
#    Gender  Age
# 1  Female   41
# 4  Female   43
# 5    Male   44

# %% [markdown]
# ### iloc

# %%
df_small.head()
# Out:
#    Geography  Gender  Age
# 1      Spain  Female   41
# 4      Spain  Female   43
# 5      Spain    Male   44
# 11     Spain    Male   24
# 14     Spain  Female   35

# %%
df_small.iloc[[0, 1, 2]]       # берём элементы по порядку
# Out:
#   Geography  Gender  Age
# 1     Spain  Female   41
# 4     Spain  Female   43
# 5     Spain    Male   44

# %%
df_small.shape  #  размерность таблицы
# Out:
# (2477, 3)

# %%
df_small.iloc[2500]     # бесли берём индекс которого нет или выходим за пределы размера таблицы то будет ошибка
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_8568\2754226102.py in <module>
# ----> 1 df_small.iloc[2500]
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexing.py in __getitem__(self, key)
#     965
#     966             maybe_callable = com.apply_if_callable(key, self.obj)
# --> 967             return self._getitem_axis(maybe_callable, axis=axis)
#     968
#     969     def _is_scalar_access(self, key: tuple):
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexing.py in _getitem_axis(self, key, axis)
#    1521
#    1522             # validate the location
# -> 1523             self._validate_integer(key, axis)
#    1524
#    1525             return self.obj._ixs(key, axis=axis)
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexing.py in _validate_integer(self, key, axis)
# ...

# %%
df_small.iloc[0, [0, 2]]  #  берём строчки и столбики через (,) в начале строчки 0, потом столбики [0, 2]
# Out:
# Geography    Spain
# Age             41
# Name: 1, dtype: object

# %% [markdown]
# ### Сортировки

# %%
df.sort_values('Age') # по возрасту от маленького до большого
# Out:
#       RowNumber  CustomerId      Surname  CreditScore Geography  Gender  Age  \
# 3512       3513    15657779       Boylan          806     Spain    Male   18
# 1678       1679    15569178    Kharlamov          570    France  Female   18
# 3517       3518    15757821      Burgess          771     Spain    Male   18
# 9520       9521    15673180  Onyekaozulu          727   Germany  Female   18
# 2021       2022    15795519     Vasiliev          716   Germany  Female   18
# ...         ...         ...          ...          ...       ...     ...  ...
# 3387       3388    15798024         Lori          537   Germany    Male   84
# 3033       3034    15578006          Yao          787    France  Female   85
# 2458       2459    15813303      Rearick          513     Spain    Male   88
# 6759       6760    15660878        T'ien          705    France    Male   92
# 6443       6444    15764927       Rogova          753    France    Male   92
#
# ...

# %%
df.sort_values('Age', ascending=False)    # по возрасту  ascending - от самого большого до маленького
# Out:
#       RowNumber  CustomerId      Surname  CreditScore Geography  Gender  Age  \
# 6443       6444    15764927       Rogova          753    France    Male   92
# 6759       6760    15660878        T'ien          705    France    Male   92
# 2458       2459    15813303      Rearick          513     Spain    Male   88
# 3033       3034    15578006          Yao          787    France  Female   85
# 3387       3388    15798024         Lori          537   Germany    Male   84
# ...         ...         ...          ...          ...       ...     ...  ...
# 9782       9783    15728829       Weigel          509    France    Male   18
# 2141       2142    15758372      Wallace          674    France    Male   18
# 9501       9502    15634146          Hou          835   Germany    Male   18
# 9520       9521    15673180  Onyekaozulu          727   Germany  Female   18
# 1619       1620    15770309     McDonald          656    France    Male   18
#
# ...

# %%
df.sort_values(['Age', 'CreditScore'])  # если есть неразрешённые конфликты сортировки берём дополнительный признак (совмещаем)
# Out:
#       RowNumber  CustomerId          Surname  CreditScore Geography  Gender  \
# 9782       9783    15728829           Weigel          509    France    Male
# 1678       1679    15569178        Kharlamov          570    France  Female
# 9029       9030    15722701            Bruno          594   Germany    Male
# 7334       7335    15759133          Vaguine          616    France    Male
# 9526       9527    15665521  Chiazagomekpele          642   Germany    Male
# ...         ...         ...              ...          ...       ...     ...
# 3387       3388    15798024             Lori          537   Germany    Male
# 3033       3034    15578006              Yao          787    France  Female
# 2458       2459    15813303          Rearick          513     Spain    Male
# 6759       6760    15660878            T'ien          705    France    Male
# 6443       6444    15764927           Rogova          753    France    Male
#
# ...
